# %%
import pandas as pd

# %%
summary_file = "/home/kunal/tscc_projects/tanner/data/family3/microbiome/14009b/summary/Schork-11-samples-taxon-and-function.xlsx"

# %%
dfs = pd.read_excel(summary_file, sheetname=None)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-9-df802a1b085b> in <module>()
# ----> 1 dfs = pd.read_excel(summary_file, sheetname=None)
#
# /home/kunal/anaconda/lib/python2.7/site-packages/pandas/io/excel.pyc in read_excel(io, sheetname, **kwds)
#     130     engine = kwds.pop('engine', None)
#     131
# --> 132     return ExcelFile(io, engine=engine).parse(sheetname=sheetname, **kwds)
#     133
#     134
#
# /home/kunal/anaconda/lib/python2.7/site-packages/pandas/io/excel.pyc in parse(self, sheetname, header, skiprows, skip_footer, index_col, parse_cols, parse_dates, date_parser, na_values, thousands, chunksize, convert_float, has_index_names, converters, **kwds)
#     245                                  convert_float=convert_float,
#     246                                  converters=converters,
# --> 247                                  **kwds)
#     248
# ...

# %%
dfs
# Out:
#                                                                                          001_002_Microbial_Fecal_Sample_9.45_07-12-14  \
# phylum                      taxid   name                                                                                          NaN
# Verrucomicrobia             -2157   Unnamed class in Archaea superkingdom                                                6.517176e-07
# NaN                         -2      Unnamed class in Bacteria superkingdom                                               7.422159e-06
# Acidobacteria               -57723  Unnamed class in Acidobacteria phylum                                                3.135270e-06
# NaN                         204432  Acidobacteriia                                                                       6.221337e-06
#                             332159  Solibacteres                                                                         2.114993e-06
# ...
