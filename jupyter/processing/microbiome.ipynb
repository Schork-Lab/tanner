# %%
import pandas as pd
import os
from datetime import datetime

# %%
microbiome_path = "/home/kunal/tscc_projects/tanner/data/family3/microbiome/14009b/"

# %%
# !cat $microbiome_path/README.txt
# Out:
# List of files and directories in this folder
#
# README.txt: 	this file
#
# Samples.txt: 	a text file with a list of sample names
#         For projects that we received samples by batches, and we processed and annotated these samples
#         by batches, there will be additional files <Sample-batch-number.txt>.
#
# Sample directories: 	each sample directory has a list of files:
#         taxonomy-data: 		taxonomy binning results for all genomes in HLI's reference genome database
#         superkingdom-reads-count.txt:	number of reads mapped to different superkingdoms
#
#         assembles.fna:		assemble sequences in FASTA format
#         assembles-cov:		average coverage of assembles
#         species-bins-assembles:	assembles binned at species level
#         ORF.faa:		ORF sequences predicted from assembles in FASTA format
#         ORF-cov:		average coverage of ORFs
#         species-bins-ORFs:	ORFs binned at species level
#         ORF-single.faa:		ORF sequences predicted from un-assembled reads in FASTA format
#
#         Bacteria-phylum-abundance.txt:	relative abundance at phylum level within Bacteria and Archaea species
#         Bacteria-class-abundance.txt:	at class level
#         Bacteria-order-abundance.txt:	at order level
#         Bacteria-family-abundance.txt:	at family level
#         Bacteria-genus-abundance.txt:	at genus level
#         Bacteria-species-abundance.txt: at species level
#         Bacteria-toprank-abundance.txt: at most top taxonomy rank
#
#         Eukaryota-phylum-abundance.txt:	relative abundance within Eukaryota species
#         Eukaryota-class-abundance.txt
#         Eukaryota-order-abundance.txt
#         Eukaryota-family-abundance.txt
#         Eukaryota-genus-abundance.txt
#         Eukaryota-species-abundance.txt
#         Eukaryota-toprank-abundance.txt
#
#         Viruses-phylum-abundance.txt:	relative abundance within viruses
#         Viruses-class-abundance.txt
#         Viruses-order-abundance.txt
#         Viruses-family-abundance.txt
#         Viruses-genus-abundance.txt
#         Viruses-species-abundance.txt
#         Viruses-toprank-abundance.txt
#
#         cog-ann.txt:			COG annotation at family level
#         cog-class-ann.txt:		COG annotation at class level
#         kog-ann.txt:			KOG annotation at family level
#         kog-class-ann.txt:		KOG annotation at class level
#         pfam-ann.txt:			Pfam annotation at domain/family level
#         tigrfam-ann.txt:		Tigrfam annotation at domain/family level
#         tigrfam-subrole-ann.txt:	Tigrfam annotation at subrole level
#         tigrfam-mainrole-ann.txt:	Tigrfam annotation at mainrole level
#         protein-ann.txt:		Proteins found in HLI reference protein database
#
#         More information of file format for taxonomy and function annotation is available in following section:
#
#         pathways directory:		This directory has pathway data for the species bins. Each species bin is either a collection of contigs that have the same species assignment or it consists of a single contig (>100 Kbp) that does not have a species level taxonomic assignment. For each species bin, there are following files:
# 		pathways-bin-speces-taxid.txt: 	pathway report generated by Pathway tools
# 		Pathways-bin-speces-taxid:	pathways found
# 		Compounds-bin-speces-taxid:	compounds found
# 		Operons-bin-speces-taxid:	operons found
# 		Proteins-bin-speces-taxid:	proteins found
# 		Reactions-bin-speces-taxid:	reactions found
# 		TC-bin-speces-taxid:		transport chemicals found
# 		Transporters-bin-speces-taxid:	transporters found
#
# 	More information for pathway annotations is available at the end of this README file for following files
# 		Compounds-orgs-cnts:		Compounds_matrix:
# 		Pathways-orgs-cnts:		Pathways_matrix
# 		Proteins-orgs-cnts:		Proteins_matrix
# 		Reactions-orgs-cnts:		Reactions_matrix
# 		TAM-orgs-cnts:			TAM_matrix
# 		TC-orgs-cnts:			TC_matrix
# 		Transporters-orgs-cnts:		Transporters_matrix
#
# ==================== More information of taxonomy and function annotation ====================
#
# In files cog-ann.txt, kog-ann.txt, pfam-ann.txt tigrfam-ann.txt and protein-ann.txt
# 	No_refs: 	number of ORFs hit the reference protein or protein family
# 	Coverage:	coverage of this reference family, which is total aligned length multipled by ORF depth
# 			from all the ORFs that hit this reference divided by the length of the reference protein
# 	Abundance:	relative abundance across all referende protein
#
# In files cog-class-ann.txt, kog-class-ann.txt, tigrfam-subrole-ann.txt tigrfam-mainrole-ann.txt
# 	No_families:	number of protein families (e.g. cog families) in this class
# 	Coverage:	number of protein families found in this sample divided by number of protein families
# 	Abundance:	sum of abundance from each protein families found in this sample
#
# In file species-bins-assembles
# 	A new bin starts with one line ">>>> taxid tax_name genome_length num_contigs len_contigs genome_cov" and followed by
# 	a list of contig names in this bin
#
# In file species-bins-ORFs
# 	A new bin starts with one line ">>>> taxid tax_name num_ORFS" and followed by
#         a list of ORF names in this bin
#
#
# ==================== More information of pathway annotation ====================
#
# In Pathway annotations, classes "describe general types of biological objects,
# such as the class of all genes". Each file with one of the following names in
# the pathways directories contains a list of class instances from the MetaCyc pgdb
# (Pathways/Genome Database). The taxonomic distribution of MetaCyc can be
# found at http://metacyc.org/META/meta-org-pwy-stats.
#
# Compounds
# Operons
# Pathways
# Proteins
# Reactions
# TAM
# TC
# Transporters
#
# Each class is described as follows in the Pathway Tools version 18.5 User's Guide:
#
# Compounds
# ---------
# The Class Compounds describe small-molecular-weight chemical compounds typically,
# compounds that are substrates of metabolic reactions or compounds that activate or
# inhibit metabolic enzymes.
#
# Operons
# -------
# Operons refer to multiple-gene transcription units only, whereas 'transcription
# units' or 'TUs' include both operons and single-gene transcription units.
#
# Pathways
# --------
# Frames in class Pathways encode metabolic and signaling pathways.
#
# Proteins
# --------
# The class of all proteins is divided into two subclasses: protein complexes and polypeptides.
# A polypeptide is a single amino acid chain produced from a single gene. A protein complex
# is a multimeric aggregation of more than one polypeptide subunit. A protein complex may in
# some cases have another protein complex as a component. Many of the slots that are applicable
# to Proteins are also applicable to members of the RNA class.
#
# Reactions
# ---------
# Frames within the Reactions class describe properties of a biochemical reaction independent
# of any enzyme or enzymes that catalyze that reaction. A reaction is a biochemical transformation
# that interconverts two sets of chemical compounds (which includes small metabolites, proteins,
# and DNA regions), and may translocate compounds from one cellular compartment to another.
# Most reactions are written in a conventional direction that has been assigned by the Enzyme Nomencla
# ture Commission, but that direction may or may not be the predominate physiological direction of
# the reaction. Reaction substrates can include small-molecular-weight compounds
# (for metabolic reactions), proteins (such as in signaling pathways), and DNA sites
# (such as for reactions involving binding of transcription factors to DNA).
#
# TAM
# ---
# "Transport Across Membrane" is the output of the all_transport_across function from the pythoncyc api.
# The function returns a list of transport proteins that transport across one of the given membranes,
# which defaults to CCO-MEMBRANES defined by the Cellular Component Ontology,
# http://geneontology.org/page/cellular-component-ontology-guidelines.
#
# TC
# ---
# "Transport Chemicals" is the output of the all_transport_chemicals function from the pythoncyc api.
# The function enumerates all chemicals transported by transport reactions in a species bin.
#
# Transporters
# ------------
# Proteins predicted by Pathway Tools' Transport Inference Parser (TIP), which identifies proteins
# in a species bin that are likely to catalyze transport reactions.
#
#
# Files and File Formats
# ----------------------
# The <class> placeholder represents a class as previously described. A file called Compounds,
# for example, lists all instances of the class compound from the pgdb of a species bin.
# Files and file formats are described below. File columns are tab delimited.
#
# <class>: List of class instances in MetaCyc.
# format:    frame-id    common_name
#
# <class>-<species bin number>-<species>-<taxid>:    Class instances found for each species bin.
# format:    frame-id    common_name
#
# <class>-orgs-cnts:    Counts of class instances found across all species bins.
# format:    count    frame-id    common_name
#
# <class>_matrix:    A matrix of the number of times each MetaCyc class instance was found in each species bin.
# Column N+1 of the matrix corresponds to the Nth row in the <class> file. If a <class>-meta_cnts file is empty,
# then the <class>_matrix file will be a matrix of zeros. This matrix is not available for the Operons class.
#
# format: species_bin1    count_of_compound1    count_of_compound2    count_of_compound3    ... etc
#         species_bin2    count_of_compound1    count_of_compound2    count_of_compound3    ... etc
#         species_bin3    count_of_compound1    count_of_compound2    count_of_compound3    ... etc
#             .                    .                    .                    .
#             .                    .                    .                    .
#             .                    .                    .                    .
#            etc                  etc                  etc                  etc

# %%
manifest = "/home/kunal/tscc_projects/tanner/doc/Nof1samples_manifest.xlsx"
manifest = pd.read_excel(manifest, )

# %%
manifest.head()
# Out:
#    FamilyID Individual ID      Date         Type  Tissue    VendorID  \
# 0         1          CaLo  04-16-14  Metabolites  Plasma  JCVI-00001
# 1         1          CaLo  04-16-14  Metabolites  Plasma  JCVI-00002
# 2         1          CaLo  07-11-14  Metabolites  Plasma  JCVI-00003
# 3         1          CaLo  09-25-14  Metabolites  Plasma  JCVI-00008
# 4         1          MaLo  09-25-14  Metabolites  Plasma  JCVI-00009
#
#    Individual ID 2                               Sample ID 1  \
# 0                2  001_CaLo_04-16-14_Metabolites_JCVI-00001
# 1                2  001_CaLo_04-16-14_Metabolites_JCVI-00002
# 2                2  001_CaLo_07-11-14_Metabolites_JCVI-00003
# 3                2  001_CaLo_09-25-14_Metabolites_JCVI-00008
# 4                3  001_MaLo_09-25-14_Metabolites_JCVI-00009
#
#                                       Sample ID 2  Unnamed: 9 Individual Key  \
# 0  001_002_Metabolites_Plasma_JCVI-00001_04-16-14         NaN           TaLo
# 1  001_002_Metabolites_Plasma_JCVI-00002_04-16-14         NaN           CaLo
# 2  001_002_Metabolites_Plasma_JCVI-00003_07-11-14         NaN           MaLo
# 3  001_002_Metabolites_Plasma_JCVI-00008_09-25-14         NaN           GrLo
# 4  001_003_Metabolites_Plasma_JCVI-00009_09-25-14         NaN           ElGo
#
#    Unnamed: 11  Family Key  Unnamed: 13
# 0            1  Longstreet            1
# 1            2         NaN          NaN
# 2            3         NaN          NaN
# 3            4         NaN          NaN
# 4            5         NaN          NaN

# %%
samples = [sample for sample in os.listdir(microbiome_path)
           if os.path.isdir(os.path.join(microbiome_path, sample)) and 
           sample not in ['Fastq', 'summary', 'new']]

# %%
sample_map = dict((sample, manifest[manifest['VendorID'] == sample]['Sample ID 2'].values[0])
                  for sample in samples)
sort_by_date = lambda x: datetime.strptime(x[1].split('_')[-1], "%m-%d-%y")
sorted_sample_map = sorted(sample_map.items(), key=sort_by_date)

# %%
files = [fn for fn in os.listdir(os.path.join(microbiome_path, samples[1]))
         if fn.endswith('.txt')]
files = [fn for fn in files
         if not ((fn.startswith('Virus') and (fn.split('-')[1] != 'toprank')))]
files = [fn for fn in files
         if not fn.startswith('Virus')]
files = [fn for fn in files if fn not in ['protein-ann.txt']]
files.sort()

# %%
def create_df(fn):
    def load_df(file_path, sample_id):
        df = pd.read_table(file_path)
        indices = set(df.columns)
        file_type = os.path.basename(file_path).split('-')[0]
        if file_type in ['Eukaryota', 'Bacteria', 'Viruses']:
            indices = indices-set(['abundance'])
            indices = list(indices)
            df.set_index(indices, inplace=True, drop=True)
        elif file_type in ['superkingdom']:
            indices = indices-set(['reads_count'])
            indices = list(indices)
            df.set_index(indices, inplace=True, drop=True)
        else:
            indices = indices - set(['Coverage', 'No_orfs', 'Abundance'])
            indices = list(indices)
            df.set_index(indices, inplace=True, drop=True)
            df = df[['Abundance']]
        df.columns = [sample_id]
        return df
    dfs = []
    for sample, sample_id in sorted_sample_map:
        #print sample
        file_path = os.path.join(microbiome_path, 
                                 sample,
                                 fn)
        dfs.append(load_df(file_path, sample_id))
    return pd.concat(dfs, axis=1)

# %%
out_file = "/home/kunal/Schork-11-samples-taxon-and-function.xlsx"
writer = pd.ExcelWriter(out_file)
for fn in files:
    print fn
    df = create_df(fn).fillna(0)
    df.to_csv("/home/kunal/tscc_projects/tanner/data/family3/microbiome/14009b/new/"+fn,
             sep="\t")
    df.to_excel(writer, fn)
writer.close()
# Out:
# Bacteria-class-abundance.txt
# Bacteria-family-abundance.txt
# Bacteria-genus-abundance.txt
# Bacteria-order-abundance.txt
# Bacteria-phylum-abundance.txt
# Bacteria-species-abundance.txt
# Bacteria-toprank-abundance.txt
# Eukaryota-class-abundance.txt
# Eukaryota-family-abundance.txt
# Eukaryota-genus-abundance.txt
# Eukaryota-order-abundance.txt
# Eukaryota-phylum-abundance.txt
# Eukaryota-species-abundance.txt
# Eukaryota-toprank-abundance.txt
# cog-ann.txt
# cog-class-ann.txt
# kog-ann.txt
# kog-class-ann.txt
# pfam-ann.txt
# superkingdom-reads-count.txt
# tigrfam-ann.txt
# tigrfam-mainrole-ann.txt
# tigrfam-subrole-ann.txt
